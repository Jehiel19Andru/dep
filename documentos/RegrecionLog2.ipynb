# %% [markdown]
# ![Image](data:image/png;base64,...)

# %% [markdown]
# ![Image](data:image/png;base64,...)

# %% [markdown]
# ![Image](data:image/png;base64,...)
#
# **Accuracy**: 0.980
# **Confusion Matrix**:
# ```
# [[56232   518]
#  [ 1717 55259]]
# ```
