# %% [markdown]
# # Arboles de decision

# %% [markdown]
# ![imagen.png](attachment:83bce0d3-9e6f-4e39-9809-24c9a519bd4c.png)

# %% [markdown]
# ![imagen.png](attachment:e6f13878-9d34-4723-9853-e4c7baa739c8.png)
